# %% [markdown]
# # Predict numerical representations based on embedding model

# %%
print('INFO: transform notebook running...')
# Out:
# INFO: transform notebook running...

# %%
extracted_data_uri = "data/extracted_data.csv"  # This would be passed as an input variable

# Simulate transforming data
transformed_data_uri = "data/transformed_data.csv"
print(f"Transforming data from: {extracted_data_uri}")
print(f"Transformed data URI: {transformed_data_uri}")
