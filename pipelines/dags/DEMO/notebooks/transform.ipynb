# %% [markdown]
# # Predict numerical representations based on embedding model

# %%
from airflow.models import Variable

# %%
# Parameters
extracted_data_uri = 'default_value1'
# Out:
# INFO: transform notebook running...

# %%
print(extracted_data_uri)

# %%
transformed_data_uri="YOUR_TRANSFORMED_DATA_URI_PLACEHOLDER"
Variable.set('transformed_data_uri', transformed_data_uri)

# %%
############## AUTO GENERATED BY ELEVAITE DATA ENGINE BEGIN ###################
# ti: BUILTIN TASK INSTANCE VARIABLE

# ti.xcom_push(key='transformed_data_uri', value=TRANSFORMED_DATA_URI) # type: ignore
############## AUTO GENERATED BY ELEVAITE DATA ENGINE END ###################
