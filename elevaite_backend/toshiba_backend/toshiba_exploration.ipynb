# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("customer_data.xlsx")

# %%
df.head()

# %%
df.count()

# %%
df.columns

# %%
df[df["Part Number"].isna() == False].count()

# %%
df[df["Part Number"].isna() == False].iloc[0]

# %%
df[df["Part Number"].isna() == False].iloc[3]["Part Number"]

# %%
df[df["Part Number"].isna() == False].iloc[3]["SR Address Line 1"]

# %%
print(df[df["Part Number"].isna() == False].iloc[3]["Comments (TEXT)"])

# %%
"""
"
1. Cisco Phones Having Problems With Drive Thru - Outside Speaker Issue / Stuck
  2. 06-NOV-2024 :  TGCS | Task# 16258251| Task creation Date and time 05-NOV-2024 04:17:50 PM| Task Note Entered By ERIC.WAKEFIELD | Task Note - Reset bavsonic box under the drive thru and tested with tech. Was able to hear customer in drive thru. , 04-NOV-2024 :  ACtion taken: S/w Alexus. She stated that the phone still static. Peering FT to check., 04-NOV-2024 :  Action taken: Validated the voice port, dial peer, ephn dn, Bouced the port. Phones are in registered state. Did soft reset for all phones. need to check with store.Next step: CB, 04-NOV-2024 :  Summary : Cisco Phones Having Problems With Drive Thru - Outside Speaker Issue / StuckContact Name (First and Last) : alexus hamesDate Problem Started : 2024-11-03Description Of Problem : Outside Speaker Issue / StuckSpecify Other : Problem With : Multiple PhonesExtensions and Locations Affected : 223 224 222 234Problem Is Occurring : Consistently Phone Handset Swapped : NoPhone Cord Swapped : NoPower Problem : YesCan Customers Contact The Rx By Pressing The Button On Drive-Thru Equipment : NoAttempted 555 : YesIssue Is Occurring At : Lane 1Comments : power went out and now we cannot use the phone at drive thru-- pts cannot hear us and we cannot hear them, 04-NOV-2024 :  cust_contact_first_name: alexus hamescust_contact_last_name: Walgreenscust_contact_phone_number: 864 984 5283cust_contact_email: tgcs_machine_type: 0368-59Wtgcs_model: tgcs_item_serial_no: cust_internal_item_no: cust_internal_serial_no: cust_internal_sr_number: ORSR000002992778: INC000027576497problem_summary: Cisco Phones Having Problems With Drive Thru - Outside Speaker Issue / Stuckincident_severity: Sev 3 WGNus_postal_address_line_1: 814 E MAIN STus_postal_address_line_2: us_postal_address_line_3: us_postal_address_line_4: 12568us_postal_city: LAURENSus_postal_state: SCus_postal_zipcode: 29360 3535us_postal_country: USNote Index 1note: Case Number : CS000003017722 ; WGN Incident Number : INC000027576497 ; ServiceNow Task Number : ORSR000002992778
3.
 4.
5.  CSR Notes | TGCS  SR# 15808354 Sr note creation Date and time 04-NOV-2024 10:12:52 AM Sr Note Entered By TGCI_WALGREENS  Sr Note - Action taken: Validated the voice port, dial peer, ephn dn, Bouced the port. Phones are in registered state. Did soft reset for all phones. need to check with store.Next step: CB  CSR Notes | TGCS  SR# 15808354 Sr note creation Date and time 04-NOV-2024 10:12:52 AM Sr Note Entered By TGCI_WALGREENS  Sr Note - ACtion taken: S/w Alexus. She stated that the phone still static. Peering FT to check.  CSR Notes | TGCS  SR# 15808354 Sr note creation Date and time 04-NOV-2024 10:12:49 AM Sr Note Entered By TGCI_WALGREENS  Sr Note - Summary : Cisco Phones Having Problems With Drive Thru - Outside Speaker Issue / StuckContact Name (First and Last) : alexus hamesDate Problem Started : 2024-11-03Description Of Problem : Outside Speaker Issue / StuckSpecify Other : Problem With : Multiple PhonesExtensions and Locations Affected : 223 224 222 234Problem Is Occurring : Consistently Phone Handset Swapped : NoPhone Cord Swapped : NoPower Problem : YesCan Customers Contact The Rx By Pressing The Button On Drive-Thru Equipment : NoAttempted 555 : YesIssue Is Occurring At : Lane 1Comments : power went out and now we cannot use the phone at drive thru-- pts cannot hear us and we cannot hear them  CSR Notes | TGCS  SR# 15808354 Sr note creation Date and time 04-NOV-2024 10:06:15 AM Sr Note Entered By TGCI_WALGREENS  Sr Note - Case Number : CS000003017722 ; WGN Incident Number : INC000027576497 ; ServiceNow Task Number : ORSR000002992778: INC000027576497 ; WGN Product Name : DriveThru Communication System (Bavis) ; WGN Model Name :  ; Customer Number (Store ID) : 12568 ; WGN Priority : 4 ; Description : Cisco Phones Having Problems With Drive Thru - Outside Speaker Issue / Stuck ; WGN Problem Summary : Cisco Phones Having Problems With Drive Thru - Outside Speaker Issue / Stuck;  Historical WorkNotes :  ;   CSR Notes | Reset bavsonic box under the drive thru a"
"""

# %%
from pydantic_ai import Agent

# %%
import requests
query = "What assembly Caster part"
query = "what is the description for part number 3AC01548000"
url = "http://localhost:8001/query-chunks"
params = {
    "query": query,
    "top_k": 5
}

    # Make the POST request
response = requests.post(url, params=params)

# %%
response.json()
# Out:
# {'query': 'what is the description for part number 3AC01548000',
#  'selected_segments': [{'segment_id': 1,
#    'score': 3.057637963120664,
#    'chunks': [{'chunk_id': '8cb53af3-a0d3-42f0-ae88-889acd8633a8',
#      'chunk_text': 'The table appears in the context of a hardware service guide for troubleshooting and clearing jams in a scanner/scale cabinet lock. It lists replacement parts for the lock mechanism, including part numbers and images. The surrounding text provides instructions for removing and reinstalling components, as well as troubleshooting steps for when the lock will not engage properly. The Description is Lock Kit, High Strength (9952), the Part Number is 3AC01260200, the Picture is Image of lock kit and keys. The Description is Lock Kit, High Strength (9953), the Part Number is 3AC01260300, the Picture is Image of lock kit and keys. The Description is Lock Kit, High Strength (9954), the Part Number is 3AC01260400, the Picture is Image of lock kit and keys. The Description is Lock Kit, High Strength (9955), the Part Number is 3AC01260500, the Picture is Image of lock kit and keys. The Description is Lock Kit, High Strength (9956), the Part Number is 3AC01260600, the Picture is Image of lock kit and keys. The Description is Lock Kit, High Strength (9957), the Part Number is 3AC01260700, the Picture is Image of lock kit and keys. The Description is Lock Kit, High Strength (9958), the Part Number is 3AC01260800, the Picture is Image of lock kit and keys. The Description is Lock Kit, High Strength (9959), the Part Number is 3AC01260900, the Picture is Image of lock kit and keys. The Description is Lock Kit, High Strength (9960), the Part Number is 3AC01261000, the Picture is Image of lock kit and keys. The Description is Lock Housing, the Part Number is N/A (Order Lock Kit), the Picture is Image of lock housing. The Description is Lock Housing Retaining Clip, the Part Number is 41J9282 * **, the Picture is Image of retaining clip. The Description is Lock Cam, the Part Number is 3AC00661300 *, the Picture is Image of lock cam. The Description is Lock Cam Spacers (2X), the Part Number is 3AC00661400 ****, the Picture is Image of lock cam spacers. The Description is Right Lock Bar, the Part Number is 3AC00661200 *, the Picture is Image of right lock bar.',
#      'is_table': True,
#      'filename': 'pdf_1',
#      'page_info': 110,
#      'contextual_header': 'The table appears in the context of a hardware service guide for troubleshooting and clearing jams in a scanner/scale cabinet lock. It lists replacement parts for the lock mechanism, including part numbers and images. The surrounding text provides instructions for removing and reinstalling components, as well as troubleshooting steps for when the lock will not engage properly.',
#      'matched_image_path': '/Users/dheeraj/Desktop/yolo_img_annotation/cropped_img/pdf_1_page_110_table_0.png',
#      'search_type': 'semantic',
#      'relevance_score': 0.8374744632448137},
#     {'chunk_id': '167390ff-4459-469a-b0fb-2b18fe2ef91e',
#      'chunk_text': 'The table appears in a section of a hardware service guide related to troubleshooting and clearing jams in a scanner/scale cabinet. It lists replacement parts for the lock mechanism, including descriptions, part numbers, and pictures. The surrounding text provides instructions for removing and installing lock components, troubleshooting lock issues, and ensuring proper operation of the scanner/scale cabinet lock. The Description is Lock Kit, High Strength (9952), the Part Number is 3AC01260200, the Picture is . The Description is Lock Kit, High Strength (9953), the Part Number is 3AC01260300, the Picture is . The Description is Lock Kit, High Strength (9954), the Part Number is 3AC01260400, the Picture is . The Description is Lock Kit, High Strength (9955), the Part Number is 3AC01260500, the Picture is . The Description is Lock Kit, High Strength (9956), the Part Number is 3AC01260600, the Picture is . The Description is Lock Kit, High Strength (9957), the Part Number is 3AC01260700, the Picture is . The Description is Lock Kit, High Strength (9958), the Part Number is 3AC01260800, the Picture is . The Description is Lock Kit, High Strength (9959), the Part Number is 3AC01260900, the Picture is . The Description is Lock Kit, High Strength (9960), the Part Number is 3AC01261000, the Picture is . The Description is Lock Housing, the Part Number is N/A (Order Lock Kit), the Picture is . The Description is Lock Housing Retaining Clip, the Part Number is 41J9282, the Picture is . The Description is Lock Cam, the Part Number is 3AC00960000, the Picture is . The Description is Lock Arm Plastic Washer (2X), the Part Number is 3AC00705200, the Picture is . The Description is Left Lock Bar, the Part Number is 3AC00959600, the Picture is . The Description is Right Lock Bar, the Part Number is 3AC00959700, the Picture is . The Description is Lock Arm Screw, M5x8 (2X), the Part Number is 3AC01007700 (pack of 12), the Picture is .',
#      'is_table': True,
#      'filename': 'pdf_1',
#      'page_info': 116,
#      'contextual_header': 'The table appears in a section of a hardware service guide related to troubleshooting and clearing jams in a scanner/scale cabinet. It lists replacement parts for the lock mechanism, including descriptions, part numbers, and pictures. The surrounding text provides instructions for removing and installing lock components, troubleshooting lock issues, and ensuring proper operation of the scanner/scale cabinet lock.',
#      'matched_image_path': '/Users/dheeraj/Desktop/yolo_img_annotation/cropped_img/pdf_1_page_116_table_0.png',
#      'search_type': 'semantic',
#      'relevance_score': 0.8007674022255167},
#     {'chunk_id': '38a29130-65e9-424f-8b82-516cc8b8f31b',
#      'chunk_text': 'Index Part Number Units Description -9 3AC00597000 (01YL832) 1 Rear card cover (black) -9 3AC00746300 (01KE468) 1 Rear card cover (white) -10 3AC00597100 (01YL833) 1 Blower (fan) -11 3AC00597200 (01YL834) 1 Blower bracket and blower foam -12 3AC00597300 (01YL835) 1 Cooling duct -13 3AC00597400 (01YL836) 1 Speaker -14 3AC00597600 (01YL838) 1 Left-sided USB cable (front- sided view) -15 3AC00597500 (01YL837) 1 Right-sided USB cable (front- sided view) -17 3AC01100900 (01YL808) 1 Celeron system board (for 6200-1xC) -18 3AC01101000 (01YL640) 1 Celeron system board with W10 key (for 6200-ExC) -19 3AC01101100 (01KE483) 1 i3 system board (for 6200-1x3) -20 3AC01101200 (01KE484) ` i3 system board with W10 (for 6200-Ex3) -21 3AC01101300 (01YL635) 1 i5 system board (for 6200-1x5) -22 3AC01101400 (01YL637) 1 i5 system board with W10 key (for 6200-Ex5) -23 3AC01101500 (01YL638) 1 i7 system board (for 6200-1x7) -24 3AC01101600 (01YL636) 1 i7 system board FRU with W10 key (for 6200-Ex7) -25 3AC00598300 (01YL840) 1 Thermal pad -26 3AC00607800 (01YL577) Fingerprint reader or fingerprint reader I -27 3AC00598500 (01YL641) 1 System unit RS232 I/O Card -29 3AC00598600 (01YL642) 1 System unit USB I/O card -30 3AC00598800 (01YL843) 1 System unit cable tie bar Appendix B . Understanding this parts assembly 133',
#      'is_table': False,
#      'filename': '6200 Planning Install and Service Guide.pdf',
#      'page_info': [133],
#      'contextual_header': None,
#      'matched_image_path': None,
#      'search_type': 'semantic',
#      'relevance_score': 0.7351371951350375},
#     {'chunk_id': '6a36a997-3ce4-4856-a43f-15979af039ca',
#      'chunk_text': 'The table appears in the context of "Assembly 4: Transaction awareness light" from a parts manual. It lists parts, part numbers, units, and descriptions related to the transaction awareness light assembly. The table is part of a detailed breakdown of components for assembling or servicing this specific system. The Index is -1, the Part Number is 3AC01115300, the Units is 1, the Description is Transaction Flag Light Asm (8Q3851). The Index is -1, the Part Number is 3AC00052400, the Units is 1, the Description is Transaction Awareness Flag Light Asm, Black, System 7 (8Q4083). The Index is -2, the Part Number is 3AC01548100, the Units is 1, the Description is Globe, Transaction Awareness Light, Round (8Q4058). The Index is -3, the Part Number is 3AC01548000, the Units is 1, the Description is Transaction Awareness Light ASM, without Boot, without Globe (8Q4058). The Index is -4, the Part Number is 3AC01293100, the Units is 1, the Description is Wrap Plug for Transaction Light Flag Extension Cable (8Q3851). The Index is -5, the Part Number is 3AC01116800, the Units is 1, the Description is Transaction Light Extension Cable (included with -8, -9). The Index is -6, the Part Number is 3AC01067200, the Units is 1, the Description is Transaction Light, Green/Amber/Green with Short Cable (8Q3811). The Index is -7, the Part Number is 3AC01067100, the Units is 1, the Description is Transaction Light Pole, Short (0.5m).',
#      'is_table': True,
#      'filename': 'pdf_5',
#      'page_info': 19,
#      'contextual_header': 'The table appears in the context of "Assembly 4: Transaction awareness light" from a parts manual. It lists parts, part numbers, units, and descriptions related to the transaction awareness light assembly. The table is part of a detailed breakdown of components for assembling or servicing this specific system.',
#      'matched_image_path': '/Users/dheeraj/Desktop/yolo_img_annotation/cropped_img/pdf_5_page_19_table_0.png',
#      'search_type': 'exact_match',
#      'relevance_score': 1.0042589025152957}]},
#   {'segment_id': 2,
#    'score': 1.2301834247849168,
#    'chunks': [{'chunk_id': 'ec2c9c4a-2a3e-48f4-b63a-471a2e39af94',
#      'chunk_text': 'The table appears under the heading "Assembly 36: Standalone parts" in Chapter 5, titled "Miscellaneous." It lists parts with their part numbers, units, and descriptions. The Index is -, the Part Number is 3AC01097800, the Units is 1, the Description is Removable Front Cover, Royal Gray (8Q3833). The Index is -, the Part Number is 3AC01098200, the Units is 1, the Description is Cover Plate Kit (8Q3833).',
#      'is_table': True,
#      'filename': 'pdf_5',
#      'page_info': 101,
#      'contextual_header': 'The table appears under the heading "Assembly 36: Standalone parts" in Chapter 5, titled "Miscellaneous." It lists parts with their part numbers, units, and descriptions.',
#      'matched_image_path': '/Users/dheeraj/Desktop/yolo_img_annotation/cropped_img/pdf_5_page_101_table_0.png',
#      'search_type': 'semantic',
#      'relevance_score': 0.6816210065559289},
#     {'chunk_id': 'f4b1b010-8da5-4548-96e0-493da1dd51ba',
#      'chunk_text': 'The table appears in the context of "Assembly 3: Updated Touchscreen Lane PC Assembly" within a parts manual. It lists components related to the assembly, including part numbers, units, and descriptions. The surrounding text provides instructions on how to use the parts manual for ordering information. The Index is -1, the Part Number is 3AC01965400, the Units is 1, the Description is AIO Mount Base and Mount Locking Plate, 6800-3xx. The Index is -2, the Part Number is 3AC01617500, the Units is 1, the Description is Green Button for TCx 810. The Index is -3, the Part Number is 3AC01965500, the Units is 1, the Description is VESA Bracket, AIO Mount, 6800-3xx. The Index is -4, the Part Number is , the Units is 1, the Description is TCx 810, See TCx 810 Planning, Installation, and Service Guide for lane PC information.',
#      'is_table': True,
#      'filename': 'pdf_5',
#      'page_info': 18,
#      'contextual_header': 'The table appears in the context of "Assembly 3: Updated Touchscreen Lane PC Assembly" within a parts manual. It lists components related to the assembly, including part numbers, units, and descriptions. The surrounding text provides instructions on how to use the parts manual for ordering information.',
#      'matched_image_path': '/Users/dheeraj/Desktop/yolo_img_annotation/cropped_img/pdf_5_page_18_table_0.png',
#      'search_type': 'semantic',
#      'relevance_score': 0.7085624182289877}]}],
#  'metrics': {'total_retrieved_chunks': 6,
#   'selected_segment_count': 2,
#   'retrieval_time_ms': 1468.4460163116455,
#   'segment_selection_time_ms': 0.3178119659423828,
#   'total_processing_time_ms': 1468.9650535583496}}

# %%
segments = response.json()["selected_segments"]

# %%
for segment in segments[:3]:
    print(segment["score"])
    # chunk_info = {}
    for chunk in segment["chunks"]:

        print(chunk["chunk_text"])
    #     if chunk["contextual_header"] not in chunk_info:
    #         chunk_info[chunk["contextual_header"]] = [chunk["chunk_text"], chunk["filename"], chunk["page_info"], chunk["matched_image_path"]]
    #     else:
    #         chunk_info[chunk["contextual_header"]][0]+="\n"+(chunk["chunk_text"])
        # print(chunk["contextual_header"])
        # print(chunk["chunk_text"])
        #
        # print(chunk["filename"])
        # print(chunk["page_info"])
        # print(chunk["matched_image_path"])
    # print(chunk_info)
# Out:
# 3.057637963120664
# **************************************************
# The table appears in the context of a hardware service guide for troubleshooting and clearing jams in a scanner/scale cabinet lock. It lists replacement parts for the lock mechanism, including part numbers and images. The surrounding text provides instructions for removing and reinstalling components, as well as troubleshooting steps for when the lock will not engage properly.
# --------------------------------------------------
# The table appears in the context of a hardware service guide for troubleshooting and clearing jams in a scanner/scale cabinet lock. It lists replacement parts for the lock mechanism, including part numbers and images. The surrounding text provides instructions for removing and reinstalling components, as well as troubleshooting steps for when the lock will not engage properly. The Description is Lock Kit, High Strength (9952), the Part Number is 3AC01260200, the Picture is Image of lock kit and keys. The Description is Lock Kit, High Strength (9953), the Part Number is 3AC01260300, the Picture is Image of lock kit and keys. The Description is Lock Kit, High Strength (9954), the Part Number is 3AC01260400, the Picture is Image of lock kit and keys. The Description is Lock Kit, High Strength (9955), the Part Number is 3AC01260500, the Picture is Image of lock kit and keys. The Description is Lock Kit, High Strength (9956), the Part Number is 3AC01260600, the Picture is Image of lock kit and keys. The Description is Lock Kit, High Strength (9957), the Part Number is 3AC01260700, the Picture is Image of lock kit and keys. The Description is Lock Kit, High Strength (9958), the Part Number is 3AC01260800, the Picture is Image of lock kit and keys. The Description is Lock Kit, High Strength (9959), the Part Number is 3AC01260900, the Picture is Image of lock kit and keys. The Description is Lock Kit, High Strength (9960), the Part Number is 3AC01261000, the Picture is Image of lock kit and keys. The Description is Lock Housing, the Part Number is N/A (Order Lock Kit), the Picture is Image of lock housing. The Description is Lock Housing Retaining Clip, the Part Number is 41J9282 * **, the Picture is Image of retaining clip. The Description is Lock Cam, the Part Number is 3AC00661300 *, the Picture is Image of lock cam. The Description is Lock Cam Spacers (2X), the Part Number is 3AC00661400 ****, the Picture is Image of lock cam spacers. The Description is Right Lock Bar, the Part Number is 3AC00661200 *, the Picture is Image of right lock bar.
# **************************************************
# The table appears in a section of a hardware service guide related to troubleshooting and clearing jams in a scanner/scale cabinet. It lists replacement parts for the lock mechanism, including descriptions, part numbers, and pictures. The surrounding text provides instructions for removing and installing lock components, troubleshooting lock issues, and ensuring proper operation of the scanner/scale cabinet lock.
# --------------------------------------------------
# The table appears in a section of a hardware service guide related to troubleshooting and clearing jams in a scanner/scale cabinet. It lists replacement parts for the lock mechanism, including descriptions, part numbers, and pictures. The surrounding text provides instructions for removing and installing lock components, troubleshooting lock issues, and ensuring proper operation of the scanner/scale cabinet lock. The Description is Lock Kit, High Strength (9952), the Part Number is 3AC01260200, the Picture is . The Description is Lock Kit, High Strength (9953), the Part Number is 3AC01260300, the Picture is . The Description is Lock Kit, High Strength (9954), the Part Number is 3AC01260400, the Picture is . The Description is Lock Kit, High Strength (9955), the Part Number is 3AC01260500, the Picture is . The Description is Lock Kit, High Strength (9956), the Part Number is 3AC01260600, the Picture is . The Description is Lock Kit, High Strength (9957), the Part Number is 3AC01260700, the Picture is . The Description is Lock Kit, High Strength (9958), the Part Number is 3AC01260800, the Picture is . The Description is Lock Kit, High Strength (9959), the Part Number is 3AC01260900, the Picture is . The Description is Lock Kit, High Strength (9960), the Part Number is 3AC01261000, the Picture is . The Description is Lock Housing, the Part Number is N/A (Order Lock Kit), the Picture is . The Description is Lock Housing Retaining Clip, the Part Number is 41J9282, the Picture is . The Description is Lock Cam, the Part Number is 3AC00960000, the Picture is . The Description is Lock Arm Plastic Washer (2X), the Part Number is 3AC00705200, the Picture is . The Description is Left Lock Bar, the Part Number is 3AC00959600, the Picture is . The Description is Right Lock Bar, the Part Number is 3AC00959700, the Picture is . The Description is Lock Arm Screw, M5x8 (2X), the Part Number is 3AC01007700 (pack of 12), the Picture is .
# **************************************************
# None
# --------------------------------------------------
# Index Part Number Units Description -9 3AC00597000 (01YL832) 1 Rear card cover (black) -9 3AC00746300 (01KE468) 1 Rear card cover (white) -10 3AC00597100 (01YL833) 1 Blower (fan) -11 3AC00597200 (01YL834) 1 Blower bracket and blower foam -12 3AC00597300 (01YL835) 1 Cooling duct -13 3AC00597400 (01YL836) 1 Speaker -14 3AC00597600 (01YL838) 1 Left-sided USB cable (front- sided view) -15 3AC00597500 (01YL837) 1 Right-sided USB cable (front- sided view) -17 3AC01100900 (01YL808) 1 Celeron system board (for 6200-1xC) -18 3AC01101000 (01YL640) 1 Celeron system board with W10 key (for 6200-ExC) -19 3AC01101100 (01KE483) 1 i3 system board (for 6200-1x3) -20 3AC01101200 (01KE484) ` i3 system board with W10 (for 6200-Ex3) -21 3AC01101300 (01YL635) 1 i5 system board (for 6200-1x5) -22 3AC01101400 (01YL637) 1 i5 system board with W10 key (for 6200-Ex5) -23 3AC01101500 (01YL638) 1 i7 system board (for 6200-1x7) -24 3AC01101600 (01YL636) 1 i7 system board FRU with W10 key (for 6200-Ex7) -25 3AC00598300 (01YL840) 1 Thermal pad -26 3AC00607800 (01YL577) Fingerprint reader or fingerprint reader I -27 3AC00598500 (01YL641) 1 System unit RS232 I/O Card -29 3AC00598600 (01YL642) 1 System unit USB I/O card -30 3AC00598800 (01YL843) 1 System unit cable tie bar Appendix B . Understanding this parts assembly 133
# **************************************************
# The table appears in the context of "Assembly 4: Transaction awareness light" from a parts manual. It lists parts, part numbers, units, and descriptions related to the transaction awareness light assembly. The table is part of a detailed breakdown of components for assembling or servicing this specific system.
# --------------------------------------------------
# The table appears in the context of "Assembly 4: Transaction awareness light" from a parts manual. It lists parts, part numbers, units, and descriptions related to the transaction awareness light assembly. The table is part of a detailed breakdown of components for assembling or servicing this specific system. The Index is -1, the Part Number is 3AC01115300, the Units is 1, the Description is Transaction Flag Light Asm (8Q3851). The Index is -1, the Part Number is 3AC00052400, the Units is 1, the Description is Transaction Awareness Flag Light Asm, Black, System 7 (8Q4083). The Index is -2, the Part Number is 3AC01548100, the Units is 1, the Description is Globe, Transaction Awareness Light, Round (8Q4058). The Index is -3, the Part Number is 3AC01548000, the Units is 1, the Description is Transaction Awareness Light ASM, without Boot, without Globe (8Q4058). The Index is -4, the Part Number is 3AC01293100, the Units is 1, the Description is Wrap Plug for Transaction Light Flag Extension Cable (8Q3851). The Index is -5, the Part Number is 3AC01116800, the Units is 1, the Description is Transaction Light Extension Cable (included with -8, -9). The Index is -6, the Part Number is 3AC01067200, the Units is 1, the Description is Transaction Light, Green/Amber/Green with Short Cable (8Q3811). The Index is -7, the Part Number is 3AC01067100, the Units is 1, the Description is Transaction Light Pole, Short (0.5m).
# 1.2301834247849168
# **************************************************
# The table appears under the heading "Assembly 36: Standalone parts" in Chapter 5, titled "Miscellaneous." It lists parts with their part numbers, units, and descriptions.
# --------------------------------------------------
# The table appears under the heading "Assembly 36: Standalone parts" in Chapter 5, titled "Miscellaneous." It lists parts with their part numbers, units, and descriptions. The Index is -, the Part Number is 3AC01097800, the Units is 1, the Description is Removable Front Cover, Royal Gray (8Q3833). The Index is -, the Part Number is 3AC01098200, the Units is 1, the Description is Cover Plate Kit (8Q3833).
# **************************************************
# The table appears in the context of "Assembly 3: Updated Touchscreen Lane PC Assembly" within a parts manual. It lists components related to the assembly, including part numbers, units, and descriptions. The surrounding text provides instructions on how to use the parts manual for ordering information.
# --------------------------------------------------
# The table appears in the context of "Assembly 3: Updated Touchscreen Lane PC Assembly" within a parts manual. It lists components related to the assembly, including part numbers, units, and descriptions. The surrounding text provides instructions on how to use the parts manual for ordering information. The Index is -1, the Part Number is 3AC01965400, the Units is 1, the Description is AIO Mount Base and Mount Locking Plate, 6800-3xx. The Index is -2, the Part Number is 3AC01617500, the Units is 1, the Description is Green Button for TCx 810. The Index is -3, the Part Number is 3AC01965500, the Units is 1, the Description is VESA Bracket, AIO Mount, 6800-3xx. The Index is -4, the Part Number is , the Units is 1, the Description is TCx 810, See TCx 810 Planning, Installation, and Service Guide for lane PC information.

# %%
# Out:
# 2
