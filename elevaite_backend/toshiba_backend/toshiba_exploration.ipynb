# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("customer_data.xlsx")

# %%
df.head()
# Out:
#    SR Number SR Customer Account Number         Column1  Task Number  \
# 0   15806242                    T0BU9QG      ITX Merken   16243244.0
# 1   15806242                    T0BU9QG      ITX Merken   16244215.0
# 2   15748536                    T0BZG81  BELLA FLANADES   16199822.0
# 3   15748536                    T0BZG81  BELLA FLANADES   16199823.0
# 4   15748536                    T0BZG81  BELLA FLANADES   16200332.0
#
#      SR Incident Date      SR Closed Date          SR Severity  \
# 0 2024-11-04 11:40:49 2024-11-06 00:10:39  Standard - Standard
# 1 2024-11-04 11:40:49 2024-11-06 00:10:39  Standard - Standard
# 2 2024-10-28 11:33:27 2024-11-06 00:10:54  Standard - Standard
# 3 2024-10-28 11:33:27 2024-11-06 00:10:54  Standard - Standard
# 4 2024-10-28 11:33:27 2024-11-06 00:10:54  Standard - Standard
#
#   SR Machine Type SR Machine Model SR Machine Serial Number  ...  \
# 0            4900              785                  41BRD98  ...
# 1            4900              785                  41BRD98  ...
# 2            6145              1TN                      NaN  ...
# 3            6145              1TN                      NaN  ...
# 4            6145              1TN                      NaN  ...
#
#   Task Travel Time Hours Task Actual Time Hours Part Quantity Part Unit Cost  \
# 0                    NaN                    NaN           NaN            NaN
# 1                   0.37                   0.47           NaN            NaN
# 2                    NaN                    NaN           NaN            NaN
# 3                    NaN                    NaN           NaN            NaN
# 4                    NaN                    NaN           2.0          81.24
#
#   Part Total Cost  Part Number                    Part Description SR Country  \
# 0             NaN          NaN                                 NaN         US
# 1             NaN          NaN                                 NaN         US
# 2             NaN          NaN                                 NaN         US
# 3             NaN          NaN                                 NaN         US
# 4           81.24  3AC00576600  FRU, 6145-1TN Printer, raven black         US
#
#                            CONCAT Comments (Formula)  \
# 0   \n1. RFID-ZARA 13639-INC000022725166-TILL 9-R...
# 1   \n1. RFID-ZARA 13639-INC000022725166-TILL 9-R...
# 2   \n1. Caisse 1 l'imprimante ne sort pas de tic...
# 3   \n1. Caisse 1 l'imprimante ne sort pas de tic...
# 4   \n1. Caisse 1 l'imprimante ne sort pas de tic...
#
#                                      Comments (TEXT)
# 0   \n1. RFID-ZARA 13639-INC000022725166-TILL 9-R...
# 1   \n1. RFID-ZARA 13639-INC000022725166-TILL 9-R...
# 2   \n1. Caisse 1 l'imprimante ne sort pas de tic...
# 3   \n1. Caisse 1 l'imprimante ne sort pas de tic...
# 4   \n1. Caisse 1 l'imprimante ne sort pas de tic...
#
# [5 rows x 32 columns]

# %%
df.count()
# Out:
# SR Number                      30200
# SR Customer Account Number     30198
# Column1                        30198
# Task Number                    30046
# SR Incident Date               30200
# SR Closed Date                 30200
# SR Severity                    30200
# SR Machine Type                30199
# SR Machine Model               29864
# SR Machine Serial Number       19043
# SR Customer Problem Summary    30199
# SR Notes                       29555
# SR Resolution Summary           8599
# SR Barrier Code                  816
# Task Notes External            28101
# Task Assignee                  28139
# Task Assignee ID               28139
# SR Address Line 4              28228
# SR Address Line 1              30150
# SR City                        30112
# SR State                       27383
# SR Postal Code                 30059
# Task Travel Time Hours         11213
# Task Actual Time Hours         15718
# Part Quantity                   4687
# Part Unit Cost                  4578
# Part Total Cost                 4578
# Part Number                     4686
# Part Description                4686
# SR Country                     25883
# CONCAT Comments (Formula)      30177
# Comments (TEXT)                30177
# dtype: int64

# %%
df.columns
# Out:
# Index(['SR Number', 'SR Customer Account Number', 'Column1', 'Task Number',
#        'SR Incident Date', 'SR Closed Date', 'SR Severity', 'SR Machine Type',
#        'SR Machine Model', 'SR Machine Serial Number',
#        'SR Customer Problem Summary', 'SR Notes', 'SR Resolution Summary',
#        'SR Barrier Code', 'Task Notes External', 'Task Assignee',
#        'Task Assignee ID', 'SR Address Line 4', 'SR Address Line 1', 'SR City',
#        'SR State', 'SR Postal Code', 'Task Travel Time Hours',
#        'Task Actual Time Hours', 'Part Quantity', 'Part Unit Cost',
#        'Part Total Cost', 'Part Number', 'Part Description', 'SR Country',
#        'CONCAT Comments (Formula)', 'Comments (TEXT)'],
#       dtype='object')

# %%
df[df["Part Number"].isna() == False].count()
# Out:
# SR Number                      4686
# SR Customer Account Number     4686
# Column1                        4686
# Task Number                    4686
# SR Incident Date               4686
# SR Closed Date                 4686
# SR Severity                    4686
# SR Machine Type                4686
# SR Machine Model               4679
# SR Machine Serial Number       3170
# SR Customer Problem Summary    4686
# SR Notes                       4629
# SR Resolution Summary          1578
# SR Barrier Code                 193
# Task Notes External            4546
# Task Assignee                  4686
# Task Assignee ID               4686
# SR Address Line 4              4556
# SR Address Line 1              4685
# SR City                        4682
# SR State                       4167
# SR Postal Code                 4674
# Task Travel Time Hours            0
# Task Actual Time Hours            0
# Part Quantity                  4686
# Part Unit Cost                 4578
# Part Total Cost                4578
# Part Number                    4686
# Part Description               4686
# SR Country                     3986
# CONCAT Comments (Formula)      4683
# Comments (TEXT)                4683
# dtype: int64

# %%
df[df["Part Number"].isna() == False].iloc[0]
# Out:
# SR Number                                                               15748536
# SR Customer Account Number                                               T0BZG81
# Column1                                                           BELLA FLANADES
# Task Number                                                           16200332.0
# SR Incident Date                                             2024-10-28 11:33:27
# SR Closed Date                                               2024-11-06 00:10:54
# SR Severity                                                  Standard - Standard
# SR Machine Type                                                             6145
# SR Machine Model                                                             1TN
# SR Machine Serial Number                                                     NaN
# SR Customer Problem Summary    Caisse 1 l'imprimante ne sort pas de ticket (p...
# SR Notes                       05-NOV-2024 :  TGCS | Task# 16200332| Task cre...
# SR Resolution Summary                                                        NaN
# SR Barrier Code                                                              NaN
# Task Notes External            Action Plan | TGC61451TNUSB / IMPRIM TOSHIBA 6...
# Task Assignee                                                       Kane, Cheikh
# Task Assignee ID                                                     102409153.0
# SR Address Line 4                                                            NaN
# SR Address Line 1                                           12 AV AUGUSTE PERRET
# SR City                                                                SARCELLES
# SR State                                                                     NaN
# SR Postal Code                                                             95200
# Task Travel Time Hours                                                       NaN
# Task Actual Time Hours                                                       NaN
# Part Quantity                                                                2.0
# Part Unit Cost                                                             81.24
# Part Total Cost                                                            81.24
# Part Number                                                          3AC00576600
# Part Description                              FRU, 6145-1TN Printer, raven black
# SR Country                                                                    US
# CONCAT Comments (Formula)       \n1. Caisse 1 l'imprimante ne sort pas de tic...
# Comments (TEXT)                 \n1. Caisse 1 l'imprimante ne sort pas de tic...
# Name: 4, dtype: object

# %%
df[df["Part Number"].isna() == False].iloc[3]["Part Number"]
# Out:
# '3AC01334900'

# %%
df[df["Part Number"].isna() == False].iloc[3]["SR Address Line 1"]
# Out:
# '2115 E Dorothy Ln Unit 1'

# %%
print(df[df["Part Number"].isna() == False].iloc[3]["Comments (TEXT)"])
# Out:
#
# 1. INC7438257 Scale shutting down when gets issue to print labels. Department: Bake
#   2. 04-NOV-2024 :  TGCS | Task# 16244393| Task creation Date and time 04-NOV-2024 09:15:54 AM| Task Note Entered By NICHOLAS.GIBSON | Task Note - When I arrived on site I found that the mettler printer was printing short labels occasionally and also overheating and causing unit to turn off. Cleaned off printer assembly of adhesive which fixed short label issue and replaced the thermal printhead to fix the overheating issue. Issue resolved after replacement and cleaning.  , 04-NOV-2024 :  SLA Update - Rice ID-EXT-CSC019Original Respond By Time: 05-NOV-2024 15:00:00Original Resolve By time: 05-NOV-2024 17:00:00Respond By Adjustment Time is NULL.Skipping Task Planned End Date update. Proceeding with SLA Update.., 04-NOV-2024 :  Description: Scale shutting down when gets issue to print labels. Department: Bakery Model: PACT-M SN B733528276 IP Address: 10.161.64.105 ;Problem Summary full: INC7438257 Scale shutting down when gets issue to print labels. Department: Baker; All WorkNotes Entered before SR Creation:  ;  Facility Latitude:39.7045622. Facility Longitude :-84.1247755. FacilityCode00825-014. LocationInFacility: undefined. LaneNumber: .. MACAddress: undefined. StoreName: 00825-014-Kroger; Phone: 937-299-7475, 04-NOV-2024 :  cust_contact_first_name: B.Hargrovecust_contact_last_name: KrogerIBMcust_contact_phone_number: 9372997475cust_contact_email: tgcs_machine_type: 0336-KSAtgcs_model: tgcs_item_serial_no: undefinedcust_internal_item_no: cust_internal_serial_no: cust_internal_sr_number: ORSR000002992613: TS017741364: INC7438257problem_summary: INC7438257 Scale shutting down when gets issue to print labels. Department: Bakeincident_severity: Sev 3us_postal_address_line_1: 2115 E Dorothy Lnus_postal_address_line_2: us_postal_address_line_3: us_postal_address_line_4: 014 00825us_postal_city: Ketteringus_postal_state: OHus_postal_zipcode: 45420us_postal_country: USNote Index 1note: Description: Scale shutting down when gets issue to print labels. Department: Bakery Model:
# 3.
#  4.
# 5.  CSR Notes | TGCS  SR# 15807526 Sr note creation Date and time 04-NOV-2024 09:15:53 AM Sr Note Entered By TGCI_KROGER  Sr Note - Description: Scale shutting down when gets issue to print labels. Department: Bakery Model: PACT-M SN B733528276 IP Address: 10.161.64.105 ;Problem Summary full: INC7438257 Scale shutting down when gets issue to print labels. Department: Baker; All WorkNotes Entered before SR Creation:  ;  Facility Latitude:39.7045622. Facility Longitude :-84.1247755. FacilityCode00825-014. LocationInFacility: undefined. LaneNumber: .. MACAddress: undefined. StoreName: 00825-014-Kroger; Phone: 937-299-7475  Estimated Time | ETA  230p 11/4 Issue Resolution | When I arrived on site I found that the mettler printer was printing short labels occasionally and also overheating and causing unit to turn off. Cleaned off printer assembly of adhesive which fixed short label issue and replaced the thermal printhead to fix the overheating issue. Issue resolved after replacement and cleaning.

# %%
"""
"
1. Cisco Phones Having Problems With Drive Thru - Outside Speaker Issue / Stuck
  2. 06-NOV-2024 :  TGCS | Task# 16258251| Task creation Date and time 05-NOV-2024 04:17:50 PM| Task Note Entered By ERIC.WAKEFIELD | Task Note - Reset bavsonic box under the drive thru and tested with tech. Was able to hear customer in drive thru. , 04-NOV-2024 :  ACtion taken: S/w Alexus. She stated that the phone still static. Peering FT to check., 04-NOV-2024 :  Action taken: Validated the voice port, dial peer, ephn dn, Bouced the port. Phones are in registered state. Did soft reset for all phones. need to check with store.Next step: CB, 04-NOV-2024 :  Summary : Cisco Phones Having Problems With Drive Thru - Outside Speaker Issue / StuckContact Name (First and Last) : alexus hamesDate Problem Started : 2024-11-03Description Of Problem : Outside Speaker Issue / StuckSpecify Other : Problem With : Multiple PhonesExtensions and Locations Affected : 223 224 222 234Problem Is Occurring : Consistently Phone Handset Swapped : NoPhone Cord Swapped : NoPower Problem : YesCan Customers Contact The Rx By Pressing The Button On Drive-Thru Equipment : NoAttempted 555 : YesIssue Is Occurring At : Lane 1Comments : power went out and now we cannot use the phone at drive thru-- pts cannot hear us and we cannot hear them, 04-NOV-2024 :  cust_contact_first_name: alexus hamescust_contact_last_name: Walgreenscust_contact_phone_number: 864 984 5283cust_contact_email: tgcs_machine_type: 0368-59Wtgcs_model: tgcs_item_serial_no: cust_internal_item_no: cust_internal_serial_no: cust_internal_sr_number: ORSR000002992778: INC000027576497problem_summary: Cisco Phones Having Problems With Drive Thru - Outside Speaker Issue / Stuckincident_severity: Sev 3 WGNus_postal_address_line_1: 814 E MAIN STus_postal_address_line_2: us_postal_address_line_3: us_postal_address_line_4: 12568us_postal_city: LAURENSus_postal_state: SCus_postal_zipcode: 29360 3535us_postal_country: USNote Index 1note: Case Number : CS000003017722 ; WGN Incident Number : INC000027576497 ; ServiceNow Task Number : ORSR000002992778
3.
 4.
5.  CSR Notes | TGCS  SR# 15808354 Sr note creation Date and time 04-NOV-2024 10:12:52 AM Sr Note Entered By TGCI_WALGREENS  Sr Note - Action taken: Validated the voice port, dial peer, ephn dn, Bouced the port. Phones are in registered state. Did soft reset for all phones. need to check with store.Next step: CB  CSR Notes | TGCS  SR# 15808354 Sr note creation Date and time 04-NOV-2024 10:12:52 AM Sr Note Entered By TGCI_WALGREENS  Sr Note - ACtion taken: S/w Alexus. She stated that the phone still static. Peering FT to check.  CSR Notes | TGCS  SR# 15808354 Sr note creation Date and time 04-NOV-2024 10:12:49 AM Sr Note Entered By TGCI_WALGREENS  Sr Note - Summary : Cisco Phones Having Problems With Drive Thru - Outside Speaker Issue / StuckContact Name (First and Last) : alexus hamesDate Problem Started : 2024-11-03Description Of Problem : Outside Speaker Issue / StuckSpecify Other : Problem With : Multiple PhonesExtensions and Locations Affected : 223 224 222 234Problem Is Occurring : Consistently Phone Handset Swapped : NoPhone Cord Swapped : NoPower Problem : YesCan Customers Contact The Rx By Pressing The Button On Drive-Thru Equipment : NoAttempted 555 : YesIssue Is Occurring At : Lane 1Comments : power went out and now we cannot use the phone at drive thru-- pts cannot hear us and we cannot hear them  CSR Notes | TGCS  SR# 15808354 Sr note creation Date and time 04-NOV-2024 10:06:15 AM Sr Note Entered By TGCI_WALGREENS  Sr Note - Case Number : CS000003017722 ; WGN Incident Number : INC000027576497 ; ServiceNow Task Number : ORSR000002992778: INC000027576497 ; WGN Product Name : DriveThru Communication System (Bavis) ; WGN Model Name :  ; Customer Number (Store ID) : 12568 ; WGN Priority : 4 ; Description : Cisco Phones Having Problems With Drive Thru - Outside Speaker Issue / Stuck ; WGN Problem Summary : Cisco Phones Having Problems With Drive Thru - Outside Speaker Issue / Stuck;  Historical WorkNotes :  ;   CSR Notes | Reset bavsonic box under the drive thru a"
"""
